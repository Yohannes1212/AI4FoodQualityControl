# %%
import os
import pandas as pd
from io import StringIO
import re
import glob

# Define the data path
data_dir = './Bakery/*.s1p'
data_files = glob.glob(data_dir)

# Check if files are detected
if not data_files:
    print("No files found in the specified directory. Check the path:", data_dir)
else:
    print(f"Found {len(data_files)} files.")

# Helper function to parse filenames for metadata
def parse_filename(filepath):
    filename = os.path.basename(filepath)
    match = re.match(r'([A-B])_([1-3])_([1-9][0-9]*).s1p', filename)
    if match:
        product_type = match.group(1)
        storage_condition = int(match.group(2))
        replicate = int(match.group(3))
        return product_type, storage_condition, replicate
    else:
        raise ValueError(f"Filename format not recognized: {filename}")

# List to hold processed data
processed_data = []

# Process each file
for file in data_files:
    print(f"Processing file: {file}")
    with open(file, 'r') as f:
        # Filter out comment lines
        lines = [line for line in f if not line.startswith('#')]
    
    # Debug: Check the number of lines
    print(f"File {file} has {len(lines)} data lines after filtering.")

    # Load the data into a DataFrame
    try:
        df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
    except Exception as e:
        print(f"Error reading file {file}: {e}")
        continue
    
    # Ensure the correct number of rows (101 rows expected)
    if len(df) != 101:
        print(f"Skipping {file} due to incorrect row count ({len(df)} rows found).")
        continue
    
    # Parse labels from the filename
    try:
        product_type, storage_condition, replicate = parse_filename(file)
    except ValueError as e:
        print(e)
        continue
    
    # Create a feature vector
    new_feature = df['gain'].tolist() + df['phase'].tolist()
    
    # Add to the processed data
    processed_data.append([file, new_feature, product_type, replicate, storage_condition])

# If no data is processed, alert the user
if not processed_data:
    print("No valid data was processed. Check the file format and content.")
else:
    # Convert processed data to a DataFrame with corrected column names
    df = pd.DataFrame(processed_data, columns=['Replica', 'New Feature', 'Product_Type', 'Replicate', 'Storage_Condition'])

    # Optionally expand 'New Feature' into individual columns
    new_feature_df = pd.DataFrame(df['New Feature'].to_list(), columns=[f"Feature_{i+1}" for i in range(len(processed_data[0][1]))])

    # Combine with metadata
    combined_df = pd.concat([df[['Replica', 'Product_Type', 'Replicate', 'Storage_Condition']], new_feature_df], axis=1)

    # Encode Product Type
    combined_df['Product_Type'] = combined_df['Product_Type'].map({'A': 0, 'B': 1})  # 0 for bread, 1 for cookies

    # One-hot encode Storage Condition
    storage_one_hot = pd.get_dummies(combined_df['Storage_Condition'], prefix='storage')
    combined_df = pd.concat([combined_df.drop('Storage_Condition', axis=1), storage_one_hot], axis=1)

    # Save to CSV
    combined_df.to_csv('MMMatrix_bakery_data_encoded.csv', index=False)

    # Display the final DataFrame
    print("\nEncoded DataFrame:")
    print(combined_df.head())
# Out:
# Found 60 files.
# Processing file: ./Bakery/A_2_2.s1p
# File ./Bakery/A_2_2.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/A_2_10.s1p
# File ./Bakery/A_2_10.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/A_1_7.s1p
# File ./Bakery/A_1_7.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/A_3_5.s1p
# File ./Bakery/A_3_5.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/A_2_8.s1p
# File ./Bakery/A_2_8.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/B_1_2.s1p
# File ./Bakery/B_1_2.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/B_1_4.s1p
# File ./Bakery/B_1_4.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/A_3_9.s1p
# File ./Bakery/A_3_9.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/A_3_6.s1p
# File ./Bakery/A_3_6.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/A_3_10.s1p
# File ./Bakery/A_3_10.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/B_2_6.s1p
# File ./Bakery/B_2_6.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/B_2_1.s1p
# File ./Bakery/B_2_1.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/B_1_8.s1p
# File ./Bakery/B_1_8.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/B_3_2.s1p
# File ./Bakery/B_3_2.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/A_3_3.s1p
# File ./Bakery/A_3_3.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/A_3_1.s1p
# File ./Bakery/A_3_1.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/A_2_1.s1p
# File ./Bakery/A_2_1.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/B_1_10.s1p
# File ./Bakery/B_1_10.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/B_3_10.s1p
# File ./Bakery/B_3_10.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/A_1_3.s1p
# File ./Bakery/A_1_3.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/A_2_9.s1p
# File ./Bakery/A_2_9.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/A_3_4.s1p
# File ./Bakery/A_3_4.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/A_1_8.s1p
# File ./Bakery/A_1_8.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/A_2_7.s1p
# File ./Bakery/A_2_7.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/B_2_8.s1p
# File ./Bakery/B_2_8.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/A_1_1.s1p
# File ./Bakery/A_1_1.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/B_2_4.s1p
# File ./Bakery/B_2_4.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/B_3_3.s1p
# File ./Bakery/B_3_3.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/B_2_3.s1p
# File ./Bakery/B_2_3.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/A_1_5.s1p
# File ./Bakery/A_1_5.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/B_3_5.s1p
# File ./Bakery/B_3_5.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/A_2_3.s1p
# File ./Bakery/A_2_3.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/B_1_7.s1p
# File ./Bakery/B_1_7.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/A_1_4.s1p
# File ./Bakery/A_1_4.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/A_1_6.s1p
# File ./Bakery/A_1_6.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/B_2_7.s1p
# File ./Bakery/B_2_7.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/B_2_10.s1p
# File ./Bakery/B_2_10.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/B_2_9.s1p
# File ./Bakery/B_2_9.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/A_2_6.s1p
# File ./Bakery/A_2_6.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/B_3_6.s1p
# File ./Bakery/B_3_6.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/B_3_7.s1p
# File ./Bakery/B_3_7.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/A_1_10.s1p
# File ./Bakery/A_1_10.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/A_3_2.s1p
# File ./Bakery/A_3_2.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/A_3_7.s1p
# File ./Bakery/A_3_7.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/B_2_5.s1p
# File ./Bakery/B_2_5.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/B_3_4.s1p
# File ./Bakery/B_3_4.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/A_2_5.s1p
# File ./Bakery/A_2_5.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/B_2_2.s1p
# File ./Bakery/B_2_2.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/B_3_1.s1p
# File ./Bakery/B_3_1.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/B_3_9.s1p
# File ./Bakery/B_3_9.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/A_2_4.s1p
# File ./Bakery/A_2_4.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/A_1_2.s1p
# File ./Bakery/A_1_2.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/A_1_9.s1p
# File ./Bakery/A_1_9.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/B_3_8.s1p
# File ./Bakery/B_3_8.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/B_1_3.s1p
# File ./Bakery/B_1_3.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/B_1_1.s1p
# File ./Bakery/B_1_1.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/B_1_9.s1p
# File ./Bakery/B_1_9.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/A_3_8.s1p
# File ./Bakery/A_3_8.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/B_1_6.s1p
# File ./Bakery/B_1_6.s1p has 101 data lines after filtering.
# Processing file: ./Bakery/B_1_5.s1p
# File ./Bakery/B_1_5.s1p has 101 data lines after filtering.
#
# Encoded DataFrame:
#                Replica  Product_Type  Replicate  Feature_1  Feature_2  \
# 0   ./Bakery/A_2_2.s1p             0          2   0.987971   0.987575
# 1  ./Bakery/A_2_10.s1p             0         10   0.987374   0.987522
# 2   ./Bakery/A_1_7.s1p             0          7   0.984450   0.983590
# 3   ./Bakery/A_3_5.s1p             0          5   0.996009   0.996074
# 4   ./Bakery/A_2_8.s1p             0          8   0.982611   0.982838
#
#    Feature_3  Feature_4  Feature_5  Feature_6  Feature_7  ...  Feature_196  \
# 0   0.987458   0.988083   0.988038   0.988125   0.987456  ...    -0.108091
# 1   0.988473   0.987208   0.987924   0.987972   0.986922  ...    -0.115595
# 2   0.982222   0.982954   0.982375   0.983226   0.982393  ...    -0.138775
# 3   0.996639   0.996152   0.996580   0.995869   0.997087  ...    -0.083054
# 4   0.983332   0.982681   0.982933   0.983047   0.982245  ...    -0.131473
#
#    Feature_197  Feature_198  Feature_199  Feature_200  Feature_201  \
# 0    -0.108997    -0.106590    -0.109143    -0.110524    -0.112404
# 1    -0.116533    -0.113849    -0.116377    -0.117046    -0.118864
# 2    -0.142642    -0.143814    -0.142172    -0.145523    -0.147246
# 3    -0.083708    -0.082472    -0.082688    -0.084222    -0.086694
# 4    -0.130906    -0.129583    -0.129036    -0.132928    -0.135774
#
#    Feature_202  storage_1  storage_2  storage_3
# 0    -0.109518      False       True      False
# 1    -0.118197      False       True      False
# 2    -0.151266       True      False      False
# 3    -0.083010      False      False       True
# 4    -0.133157      False       True      False
#
# [5 rows x 208 columns]
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
# /tmp/ipykernel_6349/2204728454.py:44: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(StringIO(''.join(lines)), delim_whitespace=True, names=['frequency', 'gain', 'phase'])
